# %% [markdown]
# <a href="https://colab.research.google.com/github/Frestka/Mining_Premier_League/blob/main/ambiente_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =================================================================
# 1. SETUP AMBIENTE: CLONE & MOUNT
# =================================================================
import os
import sys

# 1.1 Monta Google Drive
from google.colab import drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 1.2 Clona il Repository (se non esiste già)
REPO_NAME = "Mining_Premier_League"
REPO_URL = "https://github.com/Frestka/Mining_Premier_League.git"

if not os.path.exists(REPO_NAME):
    # !git clone {REPO_URL}
    # %cd {REPO_NAME}
else:
    # %cd {REPO_NAME}
    # !git pull  # Aggiorna il codice se avevi già clonato

# 1.3 Configura il Python Path per vedere la cartella 'src'
sys.path.append(os.path.abspath('.'))

# 1.4 Installa le librerie dal tuo requirements.txt
# !pip install -r requirements.txt

# =================================================================
# 2. CARICAMENTO DATI
# =================================================================
from src.data_loader import load_data

# Carica il dataset (la funzione capirà da sola di essere su Colab)
df = load_data()

print("\n✅ SETUP COMPLETATO CON SUCCESSO!")
print(f"Dataset pronto: {df.shape[0]} righe caricate.")
# Out:
# /content/Mining_Premier_League/Mining_Premier_League
# Already up to date.
# ...
# Caricamento dati da: /content/drive/MyDrive/Mining_Premier_League/data/dataset.parquet
#
# ✅ SETUP COMPLETATO CON SUCCESSO!
# Dataset pronto: 607656 righe caricate.
