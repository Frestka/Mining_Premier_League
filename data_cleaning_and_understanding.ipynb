# %% [markdown]
# <a href="https://colab.research.google.com/github/Frestka/Mining_Premier_League/blob/main/data_cleaning_and_understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 1: Data Understanding & Preprocessing
# **Progetto:** Premier League Event Data 2020-21
# **Input:** `data/dataset.parquet` (dataset grezzo da Kaggle)
# **Output:** `data/processed/dataset_clean.parquet` (Silver Layer per Feature_extraction_EDA.ipynb)
#
# ---
#
# ## Obiettivo
# In assenza di un Data Dictionary ufficiale, la fase iniziale di questo notebook si concentra sull'esplorazione strutturale e semantica del dataset (Premier League 2020-21).
#
#
# ### Pipeline di questo notebook
# 1. Data Ingestion e Analisi Strutturale
# 2. Data Understanding
# 3. Data Cleaning
# 4. Salvataggio Silver Layer

# %% [markdown]
# <a href="https://colab.research.google.com/github/Frestka/Mining_Premier_League/blob/main/notebooks/Data_Cleaning_and_Understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    import os, sys
    from pathlib import Path

    REPO_NAME = "Mining_Premier_League"
    REPO_URL  = "https://github.com/Frestka/Mining_Premier_League.git"

    # Torna sempre a /content — evita la matrioska se la cella viene rieseguita
    os.chdir("/content")

    # Clona solo se non esiste già
    if not os.path.exists(REPO_NAME):
        # !git clone -q {REPO_URL}
        print("Repository clonato.")

    # Entra nella cartella del progetto
    os.chdir(REPO_NAME)
    sys.path.insert(0, os.path.abspath("."))

    # Aggiorna solo src/ — niente conflitti sui notebook
    # !git fetch -q origin
    # !git checkout -q origin/main -- src/

    # Installa dipendenze
    # !pip install -q -r requirements.txt

    # Crea cartelle data/ e data/processed/ se non esistono
    Path("data/processed").mkdir(parents=True, exist_ok=True)

    # ── Download tutti i file da Google Drive con gdown ──────────────────
    # ISTRUZIONE: sostituisci i placeholder con gli ID reali dei file Drive.
    # Per ottenere l'ID: apri il file su Drive → Condividi → Copia link.
    # L'ID è la stringa tra /d/ e /view del link.
    import gdown

    FILES = {
        "data/events_raw.csv":                  "1inDdK5hzYSGRfUxbCo9tCoeKLpkHCPSR", #csv originale
        "data/dataset.parquet":                 "1fSuDQalfh2_EANL5sulWyucHCo81xZQZ", #broze layer
        "data/processed/dataset_clean.parquet": "1gCE4B6r1wngsEorSU-7WMsGKWbHwUYwd", #silver layer
        "data/processed/features.parquet":      "1u5cHy_n9-0n_Q-lfFemevhipSdZoeHkc", #gold layer
    }

    for path, file_id in FILES.items():
        if not os.path.exists(path):
            print(f"Download {path}...")
            gdown.download(id=file_id, output=path, quiet=False, fuzzy=True)
        else:
            print(f"già presente, skip → {path}")

    print(f"\nSetup completato. Cartella: {os.getcwd()}")

else:
    # In locale: risale le cartelle fino a trovare la root (quella con src/)
    import os, sys
    from pathlib import Path
    root = Path.cwd()
    while not (root / "src").exists() and root.parent != root:
        root = root.parent
    if str(root) not in sys.path:
        sys.path.insert(0, str(root))
    os.chdir(root)
    print(f"Ambiente locale. Root progetto: {root}")
# Out:
# Repository clonato.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 87.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 101.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.5 MB/s eta 0:00:00
# Download data/events_raw.csv...
# Downloading...
# From (original): https://drive.google.com/uc?id=1inDdK5hzYSGRfUxbCo9tCoeKLpkHCPSR
# From (redirected): https://drive.google.com/uc?id=1inDdK5hzYSGRfUxbCo9tCoeKLpkHCPSR&confirm=t&uuid=374ee221-2f47-4a8f-96bd-c048ab2ec079
# To: /content/Mining_Premier_League/data/events_raw.csv
# 100%|██████████| 308M/308M [00:02<00:00, 103MB/s]
# Download data/dataset.parquet...
# Downloading...
# From: https://drive.google.com/uc?id=1fSuDQalfh2_EANL5sulWyucHCo81xZQZ
# To: /content/Mining_Premier_League/data/dataset.parquet
# 100%|██████████| 37.0M/37.0M [00:00<00:00, 41.1MB/s]
# Download data/processed/dataset_clean.parquet...
# Downloading...
# From: https://drive.google.com/uc?id=1gCE4B6r1wngsEorSU-7WMsGKWbHwUYwd
# To: /content/Mining_Premier_League/data/processed/dataset_clean.parquet
# 100%|██████████| 16.0M/16.0M [00:00<00:00, 38.4MB/s]
# Download data/processed/features.parquet...
# Downloading...
# From: https://drive.google.com/uc?id=1u5cHy_n9-0n_Q-lfFemevhipSdZoeHkc
# To: /content/Mining_Premier_League/data/processed/features.parquet
# 100%|██████████| 117k/117k [00:00<00:00, 59.4MB/s]
# Setup completato. Cartella: /content/Mining_Premier_League

# %% [markdown]
# ## Setup e Caricamento

# %%
import sys, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from pathlib import Path

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# --- CONFIGURAZIONE PERCORSI DINAMICA (METODO DATA LOADER) ---
def find_project_root():
    curr = Path.cwd()
    while not (curr / 'src').exists() and curr.parent != curr:
        curr = curr.parent
    return curr

project_root = find_project_root()
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.data_loader import load_data, save_clean_data

# Caricamento dinamico tramite data_loader
# Se il file manca, mostrera chiaramente l'errore del data_loader
df = load_data()
print(f'Dataset Bronze caricato con successo!')
print(f'Dimensioni: {df.shape[0]:,} righe x {df.shape[1]} colonne')
# Out:
# Caricamento dati da: /content/Mining_Premier_League/data/dataset.parquet
# Dataset Bronze caricato con successo!
# Dimensioni: 607,656 righe x 35 colonne

# %% [markdown]
# ## Data Understanding
#
# Osserviamo i dati grezzi: tipi, valori nulli, distribuzione degli eventi.

# %%
# Struttura generale
print("--- STRUTTURA DEL DATASET ---")
df.info()
# Out:
# --- STRUTTURA DEL DATASET ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607656 entries, 0 to 607655
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               607656 non-null  int64
#  1   id                       607656 non-null  float64
#  2   eventId                  607656 non-null  int64
#  3   minute                   607656 non-null  int64
#  4   second                   606355 non-null  float64
#  5   teamId                   607656 non-null  int64
#  6   x                        607656 non-null  float64
#  7   y                        607656 non-null  float64
#  8   expandedMinute           607656 non-null  int64
#  9   qualifiers               607656 non-null  object
#  10  satisfiedEventsTypes     607656 non-null  object
#  11  isTouch                  607656 non-null  bool
#  12  period_value             607656 non-null  int64
#  13  period_displayName       607656 non-null  object
#  14  type_value               607656 non-null  int64
#  15  type_displayName         607656 non-null  object
#  16  outcomeType_value        607656 non-null  int64
#  17  outcomeType_displayName  607656 non-null  object
#  18  playerId                 601949 non-null  float64
#  19  endX                     407111 non-null  float64
#  20  endY                     407111 non-null  float64
#  21  relatedEventId           10948 non-null   float64
#  22  relatedPlayerId          10948 non-null   float64
#  23  goalMouthZ               9231 non-null    float64
#  24  goalMouthY               9231 non-null    float64
#  25  isShot                   9232 non-null    object
#  26  blockedX                 5344 non-null    float64
#  27  blockedY                 5344 non-null    float64
#  28  cardType_value           1162 non-null    float64
#  29  cardType_displayName     1162 non-null    object
#  30  isGoal                   1024 non-null    object
#  31  name                     601949 non-null  object
#  32  position                 601949 non-null  object
#  33  shirtNo                  601949 non-null  float64
#  34  isOwnGoal                38 non-null      object
# dtypes: bool(1), float64(15), int64(8), object(11)
# memory usage: 158.2+ MB

# %%
# Analisi valori nulli
print("--- PERCENTUALE VALORI NULLI PER COLONNA ---")
null_pct = (df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
print(null_pct[null_pct > 0].round(2).astype(str) + '%')
# Out:
# --- PERCENTUALE VALORI NULLI PER COLONNA ---
# isOwnGoal               99.99%
# isGoal                  99.83%
# cardType_displayName    99.81%
# cardType_value          99.81%
# blockedY                99.12%
# blockedX                99.12%
# goalMouthZ              98.48%
# goalMouthY              98.48%
# isShot                  98.48%
# relatedPlayerId          98.2%
# relatedEventId           98.2%
# endY                     33.0%
# endX                     33.0%
# name                     0.94%
# playerId                 0.94%
# shirtNo                  0.94%
# position                 0.94%
# second                   0.21%
# dtype: object

# %%
# Distribuzione tipi di evento e periodi
print("--- TOP 15 TIPI DI EVENTO ---")
print(df['type_displayName'].value_counts().head(15))

print("\n--- DISTRIBUZIONE PERIODI DI GIOCO ---")
print(df[['period_value', 'period_displayName']].value_counts().sort_index())
# Out:
# --- TOP 15 TIPI DI EVENTO ---
# type_displayName
# Pass             391325
# BallRecovery      39690
# BallTouch         25034
# Aerial            24856
# Foul              16566
# Clearance         14514
# TakeOn            13445
# Tackle            11801
# Interception       7833
# CornerAwarded      7746
# Challenge          7220
# Dispossessed       6628
# BlockedPass        5691
# KeeperPickup       4917
# SavedShot          4774
# Name: count, dtype: int64
#
# --- DISTRIBUZIONE PERIODI DI GIOCO ---
# period_value  period_displayName
# 1             FirstHalf             299952
# 2             SecondHalf            306184
# 14            PostGame                 760
# 16            PreMatch                 760
# Name: count, dtype: int64

# %% [markdown]
# ## Data Understanding
#
# Di seguito il significato di ogni variabile, ricostruito interrogando i valori concreti.
#
# ### Identificatori e struttura
# - **`Unnamed: 0`** (`srno`): Indice intra-partita che si resetta a 0 ad ogni nuovo match. Usato per costruire il `match_id`. Non ha nome perché è l'index di un DataFrame esportato senza rinominarlo.
# - **`id`**: Identificatore univoco dell'evento (quasi — 80 eccezioni legate a OffsideGiven, vedi sotto).
# - **`eventId`**: ID alternativo con **due contatori paralleli**: alcune squadre usano 1,2,3...; altre 1.000.002, 1.000.003... per evitare collisioni. NON utilizzabile per identificare partite.
# - **`match_id`**: Colonna che costruiremo noi (non esiste nel dataset grezzo).
#
# ### Temporali
# - **`minute`**: Minuto dell'arbitro — si ferma a 45 e 90. Un gol al 47' sarà scritto come 45.
# - **`second`**: Secondi dell'evento.
# - **`expandedMinute`**: Minuto REALE incluso recupero. Da usare per analisi temporali accurate.
# - **`period_value` / `period_displayName`**: Fase di gioco. 1=FirstHalf, 2=SecondHalf, 14=PostGame, 16=PreMatch. I valori 3,4,5 (supplementari/rigori) sono teorici ma **assenti** in questo dataset (campionato PL, no playoff).
# - **`minute == 32767`**: Valore sentinella Opta — placeholder per eventi fuori dal tempo di gioco (PreMatch/PostGame). Da rimuovere.
#
# ### Squadra e giocatore
# - **`teamId`**: ID numerico squadra, 20 valori unici = 20 squadre PL.
# - **`playerId` / `name` / `position` / `shirtNo`**: Dati del giocatore. Null per eventi di sistema (Start, End, FormationSet) dove non c'è un giocatore specifico → **Null strutturale**.
# - **`position`**: 17 ruoli (GK, DR, DL, DC, DMC, MC, AMC, AML, AMR, MR, ML, FWL, FWR, FW, Sub...).
# - **`shirtNo`**: Numero di maglia in formato float (Pandas forza float quando ci sono NaN in colonne int).
#
# ### Evento
# - **`type_value` / `type_displayName`**: Tipo di evento (39 tipi: Pass, Tackle, Goal, Foul...).
# - **`outcomeType_value` / `outcomeType_displayName`**: Esito — 1/Successful o 0/Unsuccessful.
# - **`isTouch`**: True se c'è stato un contatto con la palla. False = evento amministrativo (fischio, sostituzione).
#
# ### Coordinate
# - **`x` / `y`**: Posizione di inizio evento sul campo — scala **0-100** (percentuale, non metri).
# - **`endX` / `endY`**: Posizione di arrivo. Null per eventi senza destinazione (tackle, foul) → **Null strutturale**.
#
# ### Specifiche per tiri e gol
# - **`isShot` / `isGoal` / `isOwnGoal`**: True solo sull'evento corrispondente, altrimenti NaN → **Null strutturale** (non da imputare).
# - **`goalMouthY` / `goalMouthZ`**: Coordinate porta dove il tiro ha raggiunto la linea. Null se non è un tiro → **Null strutturale**.
# - **`blockedX` / `blockedY`**: Coordinate del blocco. Null se il tiro non è stato murato → **Null strutturale**.
#
# ### Cartellini
# - **`cardType_value` / `cardType_displayName`**: 31=Yellow, 32=SecondYellow, 33=Red. Null se non è un evento Card → **Null strutturale**.
#
# ### Relazioni tra eventi
# - **`relatedEventId`**: ID dell'evento collegato (es. il passaggio che ha generato il gol → utile per calcolare gli assist).
# - **`relatedPlayerId`**: ID del giocatore correlato (es. in un fallo, chi lo subisce).
#
# ### Colonne complesse (escluse)
# - **`qualifiers`**: JSON con metadati aggiuntivi (tipo di piede, zona, 109 possibili chiavi). Esclusa per bias interpretativi — in assenza di Data Dictionary ufficiale non siamo in grado di decodificare tutti i codici in modo affidabile.
# - **`satisfiedEventsTypes`**: Array di ID numerici interni Opta (sotto-categorie). Stessa motivazione di esclusione.
#
# ---
# ### Interpretazione dei Null — strutturali vs problematici
#
# La maggior parte dei null in questo dataset è **strutturale**: il provider registra un valore solo se l'evento lo richiede. `goalMouthZ` è null perché il 98% degli eventi non è un tiro. `cardType` è null perché il 99% degli eventi non è un cartellino. Questi null **non vanno imputati** — NaN qui è l'informazione corretta.
#
# L'unica colonna con null potenzialmente problematici è `second` (~0.2% di null su eventi di gioco reale), ma non la utilizziamo nelle feature aggregate.

# %% [markdown]
# ### Identificazione delle Partite — Costruzione di `match_id`
#
# Il dataset grezzo non ha una colonna `match_id`. Abbiamo scartato `eventId` perché il suo doppio contatore parallelo (alcune partite usano 1,2,3...; altre 1.000.002, 1.000.003...) rende impossibile un tracciamento affidabile tra partite diverse.
#
# La soluzione è in `Unnamed: 0`: questo indice si resetta a **0 esattamente ad ogni fischio d'inizio** di una nuova partita. Una `cumsum()` su questa condizione produce un identificatore progressivo univoco per partita.

# %%
# Rinominiamo prima (così il reset si legge sul nome giusto)
df = df.rename(columns={'Unnamed: 0': 'srno'})

# Ordine cronologico garantito
df = df.sort_index()

# Costruzione match_id: ogni reset a 0 = nuova partita
df['match_id'] = (df['srno'] == 0).cumsum()

n_matches = df['match_id'].nunique()
print(f"Partite identificate: {n_matches}  (attese: 380 per PL 2020-21)")

# Verifica: ogni partita deve avere esattamente 2 squadre
teams_per_match = df.groupby('match_id')['teamId'].nunique()
print(f"Partite con esattamente 2 squadre: {(teams_per_match == 2).sum()} / {n_matches}")
# Out:
# Partite identificate: 380  (attese: 380 per PL 2020-21)
# Partite con esattamente 2 squadre: 380 / 380

# %% [markdown]
# ## Data Cleaning
#
# Applichiamo le operazioni di pulizia in ordine logico, documentando ogni scelta:
#
# 1. **Gestione duplicati su `id`**: 80 righe condividono lo stesso `id` a causa di eventi `OffsideGiven` registrati specularmente per entrambe le squadre (chi lo commette e chi ne beneficia). Si tratta di azioni valide → **manteniamo le righe**, ne prendiamo nota.
# 2. **Trattamento `qualifiers`**: dal campo JSON `qualifiers` abbiamo estratto le informazioni utili (booleani, numerici e categorici) tramite parsing; successivamente rimuoviamo il JSON grezzo (`qualifiers`) e `satisfiedEventsTypes` per alleggerire il dataset senza perdere le metriche estratte.
# 3. **Filtro fasi di gioco**: manteniamo `period_value` in [1,2,3,4,5] — escludiamo PreMatch (16) e PostGame (14).
# 4. **Rimozione sentinella temporale**: `minute == 32767` è un placeholder di sistema, non un evento reale.
# 5. **Casting booleani**: `isShot`, `isGoal`, `isOwnGoal` sono di tipo `object` (contengono NaN o stringa `'True'`). Convertiamo: `fillna(False)` trasforma NaN → False booleano; `astype(bool)` trasforma `'True'` → True.
# 6. **Correzione `shirtNo`**: da float a int (Pandas forza float quando ci sono NaN in colonne intere).

# %%
import pandas as pd
import numpy as np

print(f"Dimensioni prima del cleaning: {df.shape[0]:,} righe × {df.shape[1]} colonne")

# 1. Duplicati su id — rilevazione e mantenimento consapevole
n_duplicati = df['id'].duplicated().sum()
print(f"\nRighe con 'id' duplicato: {n_duplicati} → MANTENUTE (OffsideGiven speculari)")

# ==============================================================================
# 2. ESTRAZIONE QUALIFIERS (METRICHE TATTICHE AVANZATE - Metodo Vettorializzato V3)
# ==============================================================================
print("\nEstrazione feature avanzate dai qualifiers in corso (Veloce)...")

BOOL_QUALIFIERS = [
    'Longball', 'Chipped', 'Cross', 'HeadPass', 'Throughball',
    'KeyPass', 'BigChance', 'BigChanceCreated', 'Assisted', 'IntentionalAssist',
    'FastBreak', 'LayOff', 'FromCorner', 'SetPiece',
    'FreekickTaken', 'CornerTaken', 'Penalty', 'ThrowIn',
    'Blocked', 'OutfielderBlock', 'SixYardBlock', 'PlayerCaughtOffside'
]

# Estrazione Booleani (Metodo vettorializzato istantaneo)
for q in BOOL_QUALIFIERS:
    col_name = 'is_' + q.lower()
    df[col_name] = df['qualifiers'].str.contains(f"'displayName': '{q}'", na=False)

# Estrazione Numerici (Vettorializzata)
df['pass_length'] = df['qualifiers'].str.extract(r"'displayName': 'Length'\}, 'value': '([^']+)'").astype(float)
df['pass_angle'] = df['qualifiers'].str.extract(r"'displayName': 'Angle'\}, 'value': '([^']+)'").astype(float)
df['goal_mouth_y'] = df['qualifiers'].str.extract(r"'displayName': 'GoalMouthY'\}, 'value': '([^']+)'").astype(float)
df['goal_mouth_z'] = df['qualifiers'].str.extract(r"'displayName': 'GoalMouthZ'\}, 'value': '([^']+)'").astype(float)

# Estrazione Categorici (Testo)
df['zone'] = df['qualifiers'].str.extract(r"'displayName': 'Zone'\}, 'value': '([^']+)'")

# Estrazione Body Part
df['body_part'] = None
for bp in ['RightFoot', 'LeftFoot', 'Head', 'OtherBodyPart']:
    df.loc[df['qualifiers'].str.contains(f"'displayName': '{bp}'", na=False), 'body_part'] = bp

# --- SANITY CHECKS ---
print("\n--- SANITY CHECKS ESTRAZIONE ---")
keypasses = df['is_keypass'].sum()
print(f"KeyPass trovati: {keypasses} (Attesi: ~6882)")
print("Distribuzione Body Part:")
print(df['body_part'].value_counts().to_string())
# ---------------------

# 3. Rimozione colonne opache (Incluso il JSON pesante dei qualifiers)
colonne_da_scartare = ['qualifiers', 'satisfiedEventsTypes']
df_clean = df.drop(columns=[c for c in colonne_da_scartare if c in df.columns])
print(f"\nColonne grezze rimosse per pulizia: {colonne_da_scartare}")

# 4. Filtro fasi di gioco
n_before = len(df_clean)
df_clean = df_clean[df_clean['period_value'].isin([1, 2, 3, 4, 5])]
print(f"\nEventi pre/post-match rimossi: {n_before - len(df_clean):,}")

# 5. Rimozione sentinella
n_before = len(df_clean)
df_clean = df_clean[df_clean['minute'] != 32767]
print(f"Righe con minute=32767 rimosse: {n_before - len(df_clean):,}")

# 6. Casting booleani sicuri
bool_cols_native = ['isShot', 'isGoal', 'isOwnGoal']
bool_cols_qualifier = ['is_' + q.lower() for q in BOOL_QUALIFIERS]

for col in bool_cols_native:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna(False).astype(bool)

for col in bool_cols_qualifier:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype(bool)

print("\nCasting booleani applicato.")

# 7. shirtNo
if 'shirtNo' in df_clean.columns:
    df_clean['shirtNo'] = df_clean['shirtNo'].fillna(-1).astype(int)

print(f"\nDimensioni dopo il cleaning: {df_clean.shape[0]:,} righe × {df_clean.shape[1]} colonne")
# Out:
# Dimensioni prima del cleaning: 607,656 righe × 36 colonne
#
# Righe con 'id' duplicato: 80 → MANTENUTE (OffsideGiven speculari)
#
# Estrazione feature avanzate dai qualifiers in corso (Veloce)...
#
# --- SANITY CHECKS ESTRAZIONE ---
# KeyPass trovati: 6882 (Attesi: ~6882)
# Distribuzione Body Part:
# body_part
# RightFoot        12328
# Head             11898
# LeftFoot          9013
# OtherBodyPart     4983
#
# Colonne grezze rimosse per pulizia: ['qualifiers', 'satisfiedEventsTypes']
#
# Eventi pre/post-match rimossi: 1,520
# Righe con minute=32767 rimosse: 1
#
# Casting booleani applicato.
#
# Dimensioni dopo il cleaning: 606,135 righe × 62 colonne

# %%
# Verifica finale del dataset pulito
print("--- VERIFICA FINALE ---")
print(f"Partite nel dataset pulito: {df_clean['match_id'].nunique()}")
print(f"Squadre uniche: {df_clean['teamId'].nunique()}")
print(f"Periodi rimasti: {df_clean['period_displayName'].unique()}")

# FIX: Filtriamo solo le colonne booleane che esistono davvero nel dataset!
bool_cols = bool_cols_native + bool_cols_qualifier
bool_cols_presenti = [c for c in bool_cols if c in df_clean.columns]

print(f"Tipi booleani corretti: {df_clean[bool_cols_presenti].dtypes.to_dict()}")
print(f"\nNull residui (strutturali attesi):")
null_residui = df_clean.isnull().sum()
print(null_residui[null_residui > 0])
# Out:
# --- VERIFICA FINALE ---
# Partite nel dataset pulito: 380
# Squadre uniche: 20
# Periodi rimasti: ['FirstHalf' 'SecondHalf']
# Tipi booleani corretti: {'isShot': dtype('bool'), 'isGoal': dtype('bool'), 'isOwnGoal': dtype('bool'), 'is_longball': dtype('bool'), 'is_chipped': dtype('bool'), 'is_cross': dtype('bool'), 'is_headpass': dtype('bool'), 'is_throughball': dtype('bool'), 'is_keypass': dtype('bool'), 'is_bigchance': dtype('bool'), 'is_bigchancecreated': dtype('bool'), 'is_assisted': dtype('bool'), 'is_intentionalassist': dtype('bool'), 'is_fastbreak': dtype('bool'), 'is_layoff': dtype('bool'), 'is_fromcorner': dtype('bool'), 'is_setpiece': dtype('bool'), 'is_freekicktaken': dtype('bool'), 'is_cornertaken': dtype('bool'), 'is_penalty': dtype('bool'), 'is_throwin': dtype('bool'), 'is_blocked': dtype('bool'), 'is_outfielderblock': dtype('bool'), 'is_sixyardblock': dtype('bool'), 'is_playercaughtoffside': dtype('bool')}
#
# Null residui (strutturali attesi):
# second                    1301
# playerId                  4187
# endX                    199024
# endY                    199024
# relatedEventId          595187
# relatedPlayerId         595187
# goalMouthZ              596904
# goalMouthY              596904
# blockedX                600791
# blockedY                600791
# cardType_value          604973
# cardType_displayName    604973
# name                      4187
# position                  4187
# pass_length             200325
# pass_angle              200325
# goal_mouth_y            596904
# goal_mouth_z            596904
# zone                     57006
# body_part               567914
# dtype: int64

# %% [markdown]
# ## Salvataggio — Silver Layer
#
# Il dataset è ora compreso, documentato e pulito. Lo salviamo in formato Parquet (compressione snappy) per massima efficienza in lettura.
#
# I null residui visibili sopra sono tutti **strutturali** e non richiedono imputazione: verranno gestiti naturalmente dall'aggregazione per partita nel Notebook 2, dove la funzione `extract_features` usa `safe_rate()` per evitare divisioni per zero e `.mean()` che ignora i NaN per definizione.

# %%
# Salvataggio Silver Layer tramite data_loader (environment-agnostic)
save_clean_data(df_clean)

print(f'Dataset Silver salvato correttamente.')
print(f'  Dimensioni: {df_clean.shape[0]:,} righe x {df_clean.shape[1]} colonne')
print(f'  Colonne: {list(df_clean.columns)}')
# Out:
# Salvato: /content/Mining_Premier_League/data/processed/dataset_clean.parquet
#   606,135 righe x 62 colonne
# Dataset Silver salvato correttamente.
#   Dimensioni: 606,135 righe x 62 colonne
#   Colonne: ['srno', 'id', 'eventId', 'minute', 'second', 'teamId', 'x', 'y', 'expandedMinute', 'isTouch', 'period_value', 'period_displayName', 'type_value', 'type_displayName', 'outcomeType_value', 'outcomeType_displayName', 'playerId', 'endX', 'endY', 'relatedEventId', 'relatedPlayerId', 'goalMouthZ', 'goalMouthY', 'isShot', 'blockedX', 'blockedY', 'cardType_value', 'cardType_displayName', 'isGoal', 'name', 'position', 'shirtNo', 'isOwnGoal', 'match_id', 'is_longball', 'is_chipped', 'is_cross', 'is_headpass', 'is_throughball', 'is_keypass', 'is_bigchance', 'is_bigchancecreated', 'is_assisted', 'is_intentionalassist', 'is_fastbreak', 'is_layoff', 'is_fromcorner', 'is_setpiece', 'is_freekicktaken', 'is_cornertaken', 'is_penalty', 'is_throwin', 'is_blocked', 'is_outfielderblock', 'is_sixyardblock', 'is_playercaughtoffside', 'pass_length', 'pass_angle', 'goal_mouth_y', 'goal_mouth_z', 'zone', 'body_part']
